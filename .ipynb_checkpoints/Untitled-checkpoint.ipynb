# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

class Potential_method():
    def __init__(self):
        self.start_pos = np.array([0, 0])
        self.goal_pos = np.array([50, 50])

        self.object_pos = np.array([[15, 20], [20, 20]])

        self.weight_obst, self.weight_goal = 0.1, 10

        self.delt = 0.1
        self.speed = 0.1

        self.min_pos = np.array([0, 0]) 
        self.max_pos = np.array([50, 50])

        self.potential_max, self.potential_min = 1, -1

        self.minimum_dist = 10

    def obst_cal(self, x, y):
        temp_x, temp_y, tmp = 0, 0, 0
        dist = []
        obst_in_x_y = []
        temp = []

        for i, obst in enumerate(self.object_pos):
            distance = np.sqrt((x - obst[0]) ** 2 + (y - obst[1]) ** 2)
            dist.append(distance)

            if (distance < self.minimum_dist) and (min(dist) == distance):
                temp = obst
        if not temp == []:
            obst_in_x_y.append(temp)
        else:
            obst_in_x_y = []
        
        return obst_in_x_y

    def cal_pot(self, x, y, obst_target):
        print("cal_pot target is ", obst_target)
        if obst_target == []:
            obst_pot = 0
        elif (obst_target[0] == x) and (obst_target[1] == y):
            print("obst is ", obst_target[0])
            obst_pot = self.potential_max
        else:
            obst_pot = 1 / np.sqrt(np.power((x - obst_target[0]), 2) + np.power((y - obst_target[1]), 2))
            obst_pot += obst_pot * self.weight_obst

        if self.goal_pos[0] == x and self.goal_pos[1] == y:
            goal_pot = self.potential_min
        else:
            goal_pot = -1 / np.sqrt(np.power((x - self.goal_pos[0]), 2) + np.power((y - self.goal_pos[1]), 2))

        pot_all = obst_pot + self.weight_goal * goal_pot

        return pot_all

    def cal_route(self, x, y, df):
        count = 0
        while True:
            count += 1
            obst_x_y = self.obst_cal(x, y)

            vx = -(self.cal_pot(x + self.delt, y, obst_x_y) - self.cal_pot(x, y, obst_x_y)) / delt
            vy = -(self.cal_pot(x,  y + self.delt, obst_x_y) - self.cal_pot(x, y, obst_x_y)) / delt

            v = math.sqrt(vx * vx + vy * vy)

            vx /= v /speed
            vy /= v/ speed

            x += vx
            y += vy

            tmp = pd.Series([x, y, vx, vy, obst_target[0], obst_target[1]], index = df.columns)
            df = df.append(tmp, ignore_index = True)

            if goal_x - x < 0.1 and goal_y - y < 0.1:
                break
            if count > 10000:
                break
        return df

    def plot_route(self, df):
        plt.scatter(df["x"], df["y"])

        plt.plot(self.start_pos[0], self.start_pos[1], marker = "s", calor = "b", markersize = 15)
        plt.plot(self.goal_pos[0], self.goal_pos[1], marker = "s", calor = "b", markersize = 15)

        for obst in self.object_pos:
            plt.plot(obst[0], obst[1], marker = "s", colto = "r", markersize = 10)

        plt.xlim([min_pos[0], max_pos[0]])
        plt.ylim([min_pos[1], max_pos[1]])
        plt.show()

    def cal_potential_field(self):
        pot = []
        for y in range(self.min_pos[1], self.max_pos[1]):
            tmp_pot = []
            for x in range(self.min_pos[0], self.max_pos[0]):
                potential = 0

                obst_x_y = self.obst_cal(x, y)

                potential += self.cal_pot(x, y, obst_x_y)

                if potential > self.potential_max:
                    potential = self.potential_max
                elif potential < self.potential_min:
                    potential = self.potential_min

                tmp_pot.append(potential)
            pot.append(tmp_pot)
        pot = np.array(pot)
        return pot

    def plot3d(U, xm, ym):
        # グラフ表示の設定
        plt.figure(figsize=(6,4))
        fig = plt.figure(facecolor="w")
        ax = fig.add_subplot(111, projection="3d")
        ax.tick_params(labelsize=7)    # 軸のフォントサイズ
        ax.set_xlabel("x", fontsize=10)
        ax.set_ylabel("y", fontsize=10)
        ax.set_zlabel("U", fontsize=10)
        surf = ax.plot_surface(xm, ym, U, rstride=1, cstride=1, cmap=cm.coolwarm)
        plt.show()

# %%
Potential = Potential_method()
pot = Potential.cal_potential_field()
x_plot, y_plot = np.meshgrid(np.arange(Potential.min_pos[0], Potential.max_pos[0] + 1),np.arange(Potential.min_pos[1], Potential.max_pos[1] +1))
plot3d(pot, x_plot, y_plot)

df = pd.DataFrame(columns=['x','y','vx','vy','obst_x','obst_y'])
df = cal_route(start_x, start_y, df)
plot_route(df)
# Out:
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# cal_pot target is  []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-79c7fd74683a> in <module>
#       1 Potential = Potential_method()
# ----> 2 pot = Potential.cal_potential_field()
#       3 x_plot, y_plot = np.meshgrid(np.arange(Potential.min_pos[0], Potential.max_pos[0] + 1),np.arange(Potential.min_pos[1], Potential.max_pos[1] +1))
#       4 plot3d(pot, x_plot, y_plot)
#       5
#
# <ipython-input-61-81fad755a19f> in cal_potential_field(self)
#     107                 potential = 0
#     108
# --> 109                 obst_x_y = self.obst_cal(x, y)
#     110
#     111                 potential += self.cal_pot(x, y, obst_x_y)
#
# <ipython-input-61-81fad755a19f> in obst_cal(self, x, y)
#      34             if (distance < self.minimum_dist) and (min(dist) == distance):
#      35                 temp = obst
# ---> 36         if not temp == 0:
#      37             obst_in_x_y.append(temp)
#      38         else:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
